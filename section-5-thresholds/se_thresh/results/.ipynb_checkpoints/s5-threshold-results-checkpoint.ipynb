# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set() # Use default plots from seaborn
sns.set_style("white", {'axes.grid' : False}) # White background

# %%
# Read MTurk results into dataframes
s4_df = pd.read_csv('section4-original-semantic-labels.csv')
print(s4_df.shape) 
s5_df = pd.read_csv('section5-reproduction-semantic-labels.csv')
print(s5_df.shape)
# Out:
# (4000, 37)
# (9930, 39)

# %%
# Map responses to numerical values on Likert scale
label_map = { 'Strongly Agree': 5, 'Agree': 4, 'Not sure': 3, 'Disagree': 2, 'Strongly Disagree': 1}
s4_df['label'] = s4_df['Answer.semantic-similarity.label'].map(lambda s: label_map[s])
s5_df['label'] = s5_df['Answer.semantic-similarity.label'].map(lambda s: label_map[s])

# %%
print('s4 mean:', s4_df['label'].mean())
print('s5 mean:', s5_df['label'].mean())
# Out:
# s4 mean: 3.13225
# s5 mean: 4.025176233635448

# %%
print('s4.columns:', s4_df.columns)
print('s5.columns:', s5_df.columns)
# Out:
# s4.columns: Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate',
#        'Input.USE_similarity', 'Input.dataset', 'Input.original_class',
#        'Input.text1', 'Input.perturbed_class', 'Input.text2', 'Input.run_type',
#        'Answer.semantic-similarity.label', 'Approve', 'Reject', 'label'],
#       dtype='object')
# s5.columns: Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.label_1',
#        'Input.label_2', 'Input.text1', 'Input.text2', 'Input.score_1',
#        'Input.score_2', 'Input.SE_Thresh', 'Input.dataset', 'Input.SE_Model',
#        'Answer.semantic-similarity.label', 'Approve', 'Reject', 'label'],
#       dtype='object')

# %%
dataset_name_map = { 'movie_review': 'mr', 'yelp_polarity': 'yelp-sentiment' }
s4_df['dataset'] = s4_df['Input.dataset'].map(lambda x: dataset_name_map.get(x,x))

# %%
s4_by_dataset = s4_df.groupby('dataset')['label'].mean().to_frame().rename(columns={ 'label': 'Original Data' })
s5_by_dataset = s5_df.groupby('Input.dataset')['label'].mean().to_frame().rename(columns={ 'label': 'Our Data' })

ax = pd.concat((s4_by_dataset, s5_by_dataset), axis=1).plot(kind='bar')
ax.set_title('Score increases by dataset')
# Out:
# Text(0.5,1,'Score increases by dataset')

# %%
ax = s5_df.groupby(('Input.SE_Thresh', 'Input.SE_Model'))['label'].mean().unstack(level=-1).plot(kind='bar')
patches, labels = ax.get_legend_handles_labels()
ax.legend(patches, labels, loc='lower right')
# add horizontal line at y=4
xs = np.linspace(-5, 5)
horiz_line_data = np.array([4 for i in range(len(xs))])
ax.plot(xs, horiz_line_data, 'r--') 

plt.savefig('use-thresh-bert-and-use', format='pdf')

# %%
def _c(t):
    """ converts RGB tuple to a color format matplotlib understands """
    if len(t) == 3: #add opacity
        t = t + (255.0,)
    return [tuple((x/255. for x in t),)]

# %%
# original: get_ticks returns = [1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
use_thresh_graph_yticks = ['', '1 - Strongly Disagree', '2 - Disagree', '3 - Not Sure', '4 - Agree', '5 - Strongly Agree']

# %%
# fonts
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.5})

# make graph
bert_df = s5_df[s5_df['Input.SE_Model'] == 'BERT']
ax = bert_df.groupby('Input.SE_Thresh')['label'].mean().plot(kind='bar', color=_c((75,115,164,230.)), 
                            edgecolor='black', linewidth=1.) 

#color=_c((75, 115, 165, 230.0)#
#sns.color_palette("cubehelix")
# ax = bert_df.groupby('Input.SE_Thresh')['label'].mean().plot(kind='bar'), palette="Blues_d")

# style graph
ax.set_ylim(0.0, 5.0) # This 
ax.set_yticklabels(use_thresh_graph_yticks)
# ax.set_title('Human responses across sentence encoding thresholds')
ax.set_xlabel('Minimum Cosine Similarity of BERT Sentence Embeddings')

# rotate x axis labels
# ax.set_xticklabels(ax.get_xticklabels()z, rotation=0, ha='right')

# add hatches
# Define some hatches
hatches = ['-', '+', 'x', '\\', '*', 'o']

# Loop over the bars
for i,thisbar in enumerate(ax.patches):
    # Set a different hatch for each bar
#     thisbar.set_hatch(hatches[i] * 3)
    thisbar.set_hatch('\\'*4)

# add horizontal line at y=4
xs = np.linspace(-5, 5)
horiz_line_data = np.array([4 for i in range(len(xs))])
# move numbers to above bars
# for p in ax.patches:
#     ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
#                 ha = 'center', va = 'center', xytext = (0, 15), textcoords = 'offset points')

# plot and save
ax.plot(xs, horiz_line_data, 'r--', color='red') 
plt.tight_layout()
plt.savefig('bert-thresh-final.pdf', format='pdf')

# %%
# try barh instead of bar
# i tink its worse
bert_df = s5_df[s5_df['Input.SE_Model'] == 'BERT']
ax = bert_df.groupby('Input.SE_Thresh')['label'].mean().plot(kind='barh', color=_c((75, 115, 165, 230.0)))
# style graph
ax.set_xlim(0.0, 5.0) # This 
ax.set_xticklabels(use_thresh_graph_yticks)
# ax.set_title('Human responses across sentence encoding thresholds')
ax.set_ylabel('Minimum Cosine Similarity of BERT Sentence Embeddings')
# add horizontal line at y=4
ys = np.linspace(-5, 5)
verti_line_data = np.array([4 for i in range(len(xs))])
# plot and save
ax.plot(verti_line_data, ys, 'r--', color='red') 
plt.tight_layout()
plt.savefig('bert-thresh-final-horizontal.pdf', format='pdf')

# %%
s5_df.shape
# Out:
# (9930, 40)

# %%
s4_df.groupby(('Input.run_type', 'Input.dataset'))['label'].mean()
# Out:
# Input.run_type  Input.dataset
# alzantot        imdb             2.695
# jin             imdb             3.414
#                 movie_review     3.370
#                 yelp_polarity    3.050
# Name: label, dtype: float64

# %%
bert_df[s5_df['Input.SE_Thresh'] == 0.98].groupby('Input.dataset')['label'].mean()
# Out:
# /sw/centos/anaconda3/5.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Input.dataset
# imdb              4.055102
# mr                4.181250
# yelp-sentiment    3.936842
# Name: label, dtype: float64

# %%
bert_df[s5_df['Input.SE_Thresh'] == 0.98]['Input.dataset'].value_counts()
# Out:
# /sw/centos/anaconda3/5.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# imdb              490
# mr                320
# yelp-sentiment    190
# Name: Input.dataset, dtype: int64

# %%
chosen_df = bert_df[s5_df['Input.SE_Thresh'] == 0.98]
# Out:
# /sw/centos/anaconda3/5.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
chosen_df.head()
# Out:
#                              HITId                       HITTypeId  \
# 70  3EGKVCRQFWS23NN92F565L9F66DYBG  3I7X2GF4HITNMQNSI4TO4GC73O3RHH
# 71  3EGKVCRQFWS23NN92F565L9F66DYBG  3I7X2GF4HITNMQNSI4TO4GC73O3RHH
# 72  3EGKVCRQFWS23NN92F565L9F66DYBG  3I7X2GF4HITNMQNSI4TO4GC73O3RHH
# 73  3EGKVCRQFWS23NN92F565L9F66DYBG  3I7X2GF4HITNMQNSI4TO4GC73O3RHH
# 74  3EGKVCRQFWS23NN92F565L9F66DYBG  3I7X2GF4HITNMQNSI4TO4GC73O3RHH
#
#                                                 Title  \
# 70  Does changing from text1 to text2 preserve mea...
# 71  Does changing from text1 to text2 preserve mea...
# 72  Does changing from text1 to text2 preserve mea...
# 73  Does changing from text1 to text2 preserve mea...
# 74  Does changing from text1 to text2 preserve mea...
#
#                                           Description  \
# 70  Compare two short pieces of English text and d...
# 71  Compare two short pieces of English text and d...
# 72  Compare two short pieces of English text and d...
# 73  Compare two short pieces of English text and d...
# 74  Compare two short pieces of English text and d...
#
#                                Keywords Reward                  CreationTime  \
# 70  meaning, semantic, similarity, text  $0.05  Sat Dec 07 14:31:39 PST 2019
# 71  meaning, semantic, similarity, text  $0.05  Sat Dec 07 14:31:39 PST 2019
# 72  meaning, semantic, similarity, text  $0.05  Sat Dec 07 14:31:39 PST 2019
# 73  meaning, semantic, similarity, text  $0.05  Sat Dec 07 14:31:39 PST 2019
# 74  meaning, semantic, similarity, text  $0.05  Sat Dec 07 14:31:39 PST 2019
#
#     MaxAssignments                               RequesterAnnotation  \
# 70              10  BatchId:3862237;OriginalHitTemplateId:928390905;
# 71              10  BatchId:3862237;OriginalHitTemplateId:928390905;
# 72              10  BatchId:3862237;OriginalHitTemplateId:928390905;
# 73              10  BatchId:3862237;OriginalHitTemplateId:928390905;
# 74              10  BatchId:3862237;OriginalHitTemplateId:928390905;
#
#     AssignmentDurationInSeconds  ...   \
# 70                          180  ...
# 71                          180  ...
# 72                          180  ...
# 73                          180  ...
# 74                          180  ...
#
#                                           Input.text2 Input.score_1  \
# 70  When I began watching The Muppets Take Manhatt...      0.921641
# 71  When I began watching The Muppets Take Manhatt...      0.921641
# 72  When I began watching The Muppets Take Manhatt...      0.921641
# 73  When I began watching The Muppets Take Manhatt...      0.921641
# 74  When I began watching The Muppets Take Manhatt...      0.921641
#
#     Input.score_2  Input.SE_Thresh Input.dataset Input.SE_Model  \
# 70       0.705677             0.98          imdb           BERT
# 71       0.705677             0.98          imdb           BERT
# 72       0.705677             0.98          imdb           BERT
# 73       0.705677             0.98          imdb           BERT
# 74       0.705677             0.98          imdb           BERT
#
#    Answer.semantic-similarity.label Approve Reject label
# 70                         Not sure     NaN    NaN     3
# 71                            Agree     NaN    NaN     4
# 72                   Strongly Agree     NaN    NaN     5
# 73                            Agree     NaN    NaN     4
# 74                            Agree     NaN    NaN     4
#
# [5 rows x 40 columns]

# %%
chosen_df.groupby('Input.text2')

# %%
chosen_df.groupby('Input.text2')['label'].agg(['min', 'max', 'std', 'count', 'nunique', lambda x: x.value_counts().index[0]])
# Out:
#                                                     min  max       std  count  \
# Input.text2
# "Home Room" like "Zero Day" and "Elephant", was...    2    5  1.080123     10
# . . . the photo's cleverness is paradoxically m...    3    5  0.823273     10
# ...not that all Disney films are garbage. Anywa...    3    5  0.699206     10
# A great opportunity for and Indy director to ma...    2    5  0.966092     10
# ALRIGHT, so check this out. I know I ha been lo...    1    5  1.178511     10
# Absurd. This movie is actually a vehicle for th...    4    5  0.483046     10
# After being sent to prisons for no fewer then 1...    1    5  1.100505     10
# After two long, long opening skits, one of whic...    1    5  1.316561     10
# As a child, my pals and I all believed that Gym...    3    5  0.674949     10
# Babyface - Notorious Barbara Stanwyck flick whe...    1    5  1.370320     10
# Came by on a Saturday afternoon with Calvin Har...    2    5  1.032796     10
# Even though it has one of the standard "Revenge...    2    5  0.816497     10
# For this reviewed,a list of good points and bad...    2    5  1.100505     10
# Here's a rare gem for those of you that haven't...    1    5  1.494434     10
# I am decidedly not in the target audience for t...    4    5  0.516398     10
# I catch this film on AZN on cable. It sounded l...    1    5  1.712698     10
# I finally figured out how to shop here!! And he...    2    5  1.059350     10
# I give this wedding 3 years and theres stretchi...    1    5  1.449138     10
# I just couldn't stop laughing!! This film is tr...    2    5  0.971825     10
# I love shopping at Goodwill, but this Goodwill ...    2    5  0.875595     10
# I loved watching the original Azumi with its mi...    2    5  0.875595     10
# I only know of one other movie that could possi...    4    5  0.527046     10
# I remembering this show from Swedish television...    1    5  1.429841     10
# I took my cat to this hospital because he devel...    3    5  0.632456     10
# I truly wanted to like this movie and watched a...    2    5  0.948683     10
# I watched the show 10 yr ago and adore it!!! Am...    4    5  0.483046     10
# I've never been huge on IMAX films. They're coo...    4    5  0.483046     10
# If the term itself were not geographically and ...    2    5  1.032796     10
# It used to be my thinking that movies needed pl...    3    5  0.674949     10
# Jamie's is pretty good for the cost, but nothin...    1    5  1.251666     10
# ...                                                 ...  ...       ...    ...
# a film of empty , fetishistic violence in which...    3    5  0.843274     10
# a films that plays things so nice 'n safe as to...    1    5  1.414214     10
# a hit- and-miss affair , constantly amusing but...    2    5  0.875595     10
# a shambles of a movies--visually unattractive ,...    2    5  1.100505     10
# a tough go , but leigh's depth and rigor , and ...    2    5  0.994429     10
# an exceedingly narrow in-joke targets to the ti...    4    5  0.527046     10
# as a hybrid teen thriller and murder mystery , ...    2    5  0.875595     10
# despite her unceasing vim and winsome facial sy...    4    5  0.516398     10
# feels weirdly hollow at its emotional core .          4    5  0.316228     10
# for a films that celebrate radical , nonconform...    1    5  1.370320     10
# howard and his co-stars all give committed perf...    1    5  1.197219     10
# ice age is the first computer-generated feature...    2    5  1.229273     10
# it takes a truly long , slows and dreary time t...    1    5  1.229273     10
# it's sweet , harmless , dumb , sometimes funny ...    1    5  1.449138     10
# paid in full is surprisingly engage albeit bein...    2    5  1.100505     10
# sheridan . . . smoothes over sources of conflic...    2    5  0.942809     10
# skip the movies and buy the philip glass soundt...    4    5  0.421637     10
# suffocated at conception by its munchausen-by-p...    2    5  0.994429     10
# that zhang would make such a strainingly adorab...    4    5  0.483046     10
# the characters , cast in incredibly contrived c...    2    5  0.875595     10
# the films never gets over its own investment in...    1    5  1.429841     10
# the images , scored by a perversely happy marcu...    2    5  0.994429     10
# the isolated moments of inventive madness lastl...    4    5  0.527046     10
# the movie's progression into rambling incoheren...    3    5  0.699206     10
# the so-inept- it's-surreal dubbing ( featuring ...    2    5  0.994429     10
# there are touching moments in etoiles , but for...    1    5  1.229273     10
# there's a solid woman- finding-herself story so...    3    5  0.632456     10
# this hideously earnest inversion of the concubi...    1    5  1.197219     10
# too clumsy in essential moments . . . to make a...    3    5  0.674949     10
# when it's all wet , blue crush is highly enjoya...    3    5  0.699206     10
#
#                                                     nunique  <lambda>
# Input.text2
# "Home Room" like "Zero Day" and "Elephant", was...        3         5
# . . . the photo's cleverness is paradoxically m...        3         5
# ...not that all Disney films are garbage. Anywa...        3         5
# A great opportunity for and Indy director to ma...        3         5
# ALRIGHT, so check this out. I know I ha been lo...        5         4
# Absurd. This movie is actually a vehicle for th...        2         5
# After being sent to prisons for no fewer then 1...        3         4
# After two long, long opening skits, one of whic...        4         5
# As a child, my pals and I all believed that Gym...        3         4
# Babyface - Notorious Barbara Stanwyck flick whe...        4         5
# Came by on a Saturday afternoon with Calvin Har...        3         4
# Even though it has one of the standard "Revenge...        3         4
# For this reviewed,a list of good points and bad...        3         4
# Here's a rare gem for those of you that haven't...        4         5
# I am decidedly not in the target audience for t...        2         4
# I catch this film on AZN on cable. It sounded l...        3         4
# I finally figured out how to shop here!! And he...        4         4
# I give this wedding 3 years and theres stretchi...        4         2
# I just couldn't stop laughing!! This film is tr...        3         5
# I love shopping at Goodwill, but this Goodwill ...        4         4
# I loved watching the original Azumi with its mi...        4         4
# I only know of one other movie that could possi...        2         5
# I remembering this show from Swedish television...        4         4
# I took my cat to this hospital because he devel...        3         4
# I truly wanted to like this movie and watched a...        3         5
# I watched the show 10 yr ago and adore it!!! Am...        2         5
# I've never been huge on IMAX films. They're coo...        2         5
# If the term itself were not geographically and ...        4         5
# It used to be my thinking that movies needed pl...        3         4
# Jamie's is pretty good for the cost, but nothin...        3         5
# ...                                                     ...       ...
# a film of empty , fetishistic violence in which...        3         5
# a films that plays things so nice 'n safe as to...        4         5
# a hit- and-miss affair , constantly amusing but...        3         4
# a shambles of a movies--visually unattractive ,...        4         5
# a tough go , but leigh's depth and rigor , and ...        4         5
# an exceedingly narrow in-joke targets to the ti...        2         5
# as a hybrid teen thriller and murder mystery , ...        4         4
# despite her unceasing vim and winsome facial sy...        2         4
# feels weirdly hollow at its emotional core .              2         5
# for a films that celebrate radical , nonconform...        4         5
# howard and his co-stars all give committed perf...        3         4
# ice age is the first computer-generated feature...        3         5
# it takes a truly long , slows and dreary time t...        3         5
# it's sweet , harmless , dumb , sometimes funny ...        5         5
# paid in full is surprisingly engage albeit bein...        3         4
# sheridan . . . smoothes over sources of conflic...        4         4
# skip the movies and buy the philip glass soundt...        2         5
# suffocated at conception by its munchausen-by-p...        4         5
# that zhang would make such a strainingly adorab...        2         5
# the characters , cast in incredibly contrived c...        4         4
# the films never gets over its own investment in...        4         4
# the images , scored by a perversely happy marcu...        4         4
# the isolated moments of inventive madness lastl...        2         5
# the movie's progression into rambling incoheren...        3         5
# the so-inept- it's-surreal dubbing ( featuring ...        4         5
# there are touching moments in etoiles , but for...        3         5
# there's a solid woman- finding-herself story so...        2         5
# this hideously earnest inversion of the concubi...        3         4
# too clumsy in essential moments . . . to make a...        3         5
# when it's all wet , blue crush is highly enjoya...        3         5
#
# [100 rows x 6 columns]

# %%
chosen_df.groupby('Input.text2')['label'].agg(lambda x: x.value_counts().iloc[0]).sort_values()
# Out:
# Input.text2
# OK letting's got right to the point. We have five recent colleges grads (must have majored in the F word) going out on a weekends camping trip. They run into somebody who is in needed of helped, but instead of attempting to assists him, they deciding to set him on fire instead. Nice bunch of people. Next some of them start go get sick - must be something in the water at the cabin they are staying at. However the neighbors seem to be OK. Oh well, when things starting getting really bad, they lock up one their companions instead of getting helped (attempts the neighbors by the way). Some locals don't take a liking to them. They chasing one on a high speed romp through the woods for many miles, until the truck breaks down. Somehow ten minutes later he shows up at the cabin (how he could find it and how he could journey at the speed of light to get there is a mystery). Another of the brain surgeon types at the cabin realizes something is amiss so he hides out in a cave to let this blow over. He then decides the next day to return to the cabin believing it must be some type of shrine. He is giddy with relief that he survived (he must have thought it was a 24 hour bug). Unfortuneatley he is met by some not so friendly police officers. Another couple decide to have sex while the flesh eating bug is working its magic, and then the women realizes she needs to shave her legs (taking a lot of the diseased skin with shaving cream). Anyway you get the idea. Nothing makes sense here. These are five people I would not want to be friend with. I was rooting for the flesh eating bacteria. Other characters were introduced who were also somewhat amusing but utterly unlikeable as well. Ninety minutes of good life wasted here.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# Usually, since we only ha dessert, I wouldn't review Midnight Diner until I went back for a full meal. The thing is I don't see that happening. While the decor is abundantly charming (a clean, bright rendition of the classic diner vibe), the hours are where it's at (all of them), and the cake that I tasted (a bite of chocolate and many bites of carrot) was rich and delicious the total experience was sour by the service. Our waiter hovered over our booths (his only table at the post-midnight time) and kept asking if we were ready to order even though he was literally watching us still discuss what to split. Only once we decided on the brownie sundae, which he had suggested, did he tell us they were out of some of the ingredients. Might it's because I genuinely hate feeling hurried or doing things twice, but by the time I ate fraction of my huge piece of cake I genuinely had no desired to revert. The food may be good, but there are other places to got good diner eating in the wee hours in CLT.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# for a films that celebrate radical , nonconformist values , what to do in case of fire ? lazily and glumly settles into a most traditional , reserved genre of filmmaking .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# a tough go , but leigh's depth and rigor , and his skill at inspiring accomplished portrayals that are all the more impressive for their lack of showiness , offsets to a notable degree the film's often-mined and hopeless milieu .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# I remembering this show from Swedish television. I was only 7 years of age and it terrified me beyond belief. I would love to revisit this series and see if it was just as excellent as remember though i suspect my taste and demands have changed. Although this was released before alien and a plethora of other space-thrillers i suspect that it has its root in scary movies from the 50:s and the political climate of the 70:s. When i thought of it, this was a real sci-fi, a movie trying to discuss scientific and political questions about who we are and what we are. The term sci-fi has since then become bleak and coming to be the term for any movies that has space-ships in them.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# Steve Biko was a black activist who tried to resist the white minority governed South Africa in much the same way as Gandhi tried to resist the British empire's colonialism in India. Richard Attenborough's film Cry Liberty is not about Biko or Apartheid as much as it is about Donald Woods, the white liberal newspaper editor who risked his life trying to tell Biko's story. The film ha a jarring point of view switched after Biko dies in prison from tortuous behavior at the hands of South African "police". Woods, played by Kevin Kline, must choose whether to do the right thing and flee the countries to publish books about Biko or allow his wife, played by Penelope Wilton, to pressure him into forgetting about the books. In that cases, Biko died in vain. What commencement as a life-changes friendship between Biko and Woods degenerates into a standard by the numbers escaping over the border yarn after Biko's deaths. Oscar-nominated Denzel Washington is good in only his fourth movies as Biko, but something is wrong in a film that attempt to depict the struggles of Apartheid by concentrate more on the trials of a white family for more than half the film. Attenborough would have served his topic better by focusing on Biko's rise to prominence instead of beginning where Biko befriended Woods. Perhaps a black actor in a leading role in a 2 1/2 hour film wasn't exactly conducive to big box office, but the film was a tremendous box office flop anyway. Film politics aside, the film still entertains and sends a message or two, albeit, in PG-sanitized fashion. *** of 4 stars.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# I give this wedding 3 years and theres stretching it. Adrianne Curry is fouled mouth, spoiled, controlling, vocal, and her bi sexuality past makes me laugh. She tells Chris he ha an image to protect and must avoiding strip clubs. He married her. Chris has low self esteem and from a different time warp. I have nothing against Adrianne Curry but this combination is not gonna have a happy ever after ending. Her moms said he was an old rooster and thinks this is his last attempting to recapture his youth. Here 2 very good people who are gonna end up in a nasty divorce. I don't think his old " Brady Families" is gonna fit into his new life. I see them being shutting out. Chris said his friends were more important than his families. The supported him and was there for him.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# suffocated at conception by its munchausen-by-proxy mother . punishes the vehicle to love the star .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# Here's a rare gem for those of you that haven't seen or most likely not even heard of this. During the 80s, Dennis Quaid was a hot commodity, but in the early 90s, Dennis Quaid gone from the scene. In 1993, he burst back onto the vast screen with three movies, all of which unfortunately bombed. Two of those movies I liked very much, and letting me elaborate on one of them. "Wilder Napalm" is a lunatic flick about two brothers, Wallace (Quaid) and Wilder (Arliss Howard), whom are...fire starters: yeah they have the power of pyrokinetics. Wilder has decided not to use his power anymore (for anything not useful anyway) after a fatal incident during his youths, where he and his brother blew up an abandoned dwellings which slain a man who was inside unbeknownest to them. Presently, Wilder is a fireman and is married to the wacky Vida (Debra Winger), who is under dwellings arrested for, guessing what, arson (see the movie to comprehend this better). Wilder also hasn't spoken to Wallace in 5 years, because Wallace set his hair on fire during his bachelor party. Wallace loves his pyro power and uses it for amusement. He also runs a Carnival and is the head clown. When the Carnival comes to Wilder's town, Wallace decides to reunite with his brother and also to see Vida, whom which Wallace has been in love with! Vida's house arrest sees its end, but Wilder is preoccupied. So, Wallace steps in and the fun begins. Brother vs. brother...fighting fire with fire! Some great fireball throwing in this flick...eat your heart out, Drew Barrymore! The film also has some really weird, yet funny elements, like Wilder's fire unit sings songs acapella during firefights and after wards. Jim Varney (globally known as 'Ernest') pops in as Wallace's redneck carnival buddy. "Wilder Napalm" is brilliantly shot...and cleverly put together...very off the wall and avant-guard. Give this one a look...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# the films never gets over its own investment in conventional arrangements , in terms of love , age , gender , race , and class .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# I catch this film on AZN on cable. It sounded like it would be a good film, a Japanese "Green Card". I can't say I've ever disliked an Asian film, quite the contrary. Some of the most incredible horror film of all time are Japanese and Korean, and I am a MONUMENTAL fan of John Woo's Hong Kong films. I an not negative to a light hearted film, like Tampopo or Chung King Expresses (two of my favourites), so I thought I would like this. Well, I would rather slit my wrists and drank my own blood than watch this arduous, badly acted film ever again. I thought the director Steven Okazaki must ha spiked the water with Quaalude, because no one in this film had a personality. And when any of the character DID try to act, as opposed to muttering a line or two, their performance came across as forced and terribly fake. I honestly did not think that anyone ha ever acted before...the ONLY individuals who sounded genuine was Brenda Aoki.. I find it stunning that this is promoting as a comedy, because I didn't laugh once. Even MORE startling is that CBS morning news called this "a refreshing breath of comedy". It was neither refreshing, nor a breath of comedy. And the ending was very predictable, the previous reviewer must be an idiot to think such things. AVOIDED this film unless you want to see a boring predictable plot line and wooden acting. I actually think that "Spike of Bensonhurst" is a better acted film than this...and I walked out half way through that film!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# ...
# feels weirdly hollow at its emotional core .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# there's a solid woman- finding-herself story somewhere in here , but you'd have to dig quite deep to uncover it .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# Tweaked a small bit, 'Nothing' could be a kids's film. It's a very clever concept, touches upon some interesting metaphysical topic, and goes against pretty much everything Hollywood convention you can thought of...what goes against everything more than, literally, "nothing"? Nothing is the story of two friends who wish the world away when everything goes wrong with their lives. All that's left is what they don't hate, and a big empty white space. It's hard to concentrates a story on just two actors for the majority of your movie, specially without any cuttings to anything going on outside the plot. It concentrates on pretty much one subject, but that's prime Vincenzo Natali territory. If you've seen 'Cube', you know already that he tends to like that types of situation. The "nothing" in this movie is apparently infinite space, but Natali somehow manages to make it somewhat claustrophobic, if only because there's literally nothing else, and nowhere else to go. The actors sell it, although you can tell these blokes are friends anyway. Two actors from 'Cube' reverted here (Worth and Kazan), but are altogether differing characters. They alter throughout the story, and while they're not the strongest actors in the world, they're at least believable. The reason I say this could be a children's film under the right tweaks, is because aside from a few f-bombs and a somewhat unnecessary bloody dream sequence, the whimsical and often silly feel of this movie could very much be digested easily by kids. So I find it an odd choice that the writers decided to added some crass language and a small amount of gore, especially considering there isn't very much of it. This could've gotten a PG rating easily had they simply cut a few things out and changed a little dialogue. There is very little objectionable about this film, but just enough to keep parents from wanting their kids to see it. I only say that's a shame because not because I support censorship, but because that may have been the only thing preventing this movie from having wider exposure. At any rate, this is a reasonably entertaining film, albeit with a few dragged-out scenes. But for literally being about nothing, and focused entirely on two characters and their interactions with absolutely nothing, they do a surprisingly good job for an independent film.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# Name: label, Length: 100, dtype: int64

# %%
agreed_dist = chosen_df.groupby('Input.text2')['label'].agg(lambda x: x.value_counts().iloc[0]).sort_values()

# %%
d = np.diff(np.unique(agreed_dist)).min()
left_of_first_bin = agreed_dist.min() - float(d)/2
right_of_last_bin = agreed_dist.max() + float(d)/2
plt.hist(agreed_dist, np.arange(left_of_first_bin, right_of_last_bin + d, d))
plt.show()

# %%
all_agreed_dist = bert_df.groupby(('Input.text2','Input.SE_Thresh'))['label'].agg(lambda x: x.value_counts().iloc[0]).sort_values()

# %%
d = np.diff(np.unique(all_agreed_dist)).min()
left_of_first_bin = all_agreed_dist.min() - float(d)/2
right_of_last_bin = all_agreed_dist.max() + float(d)/2
plt.hist(all_agreed_dist, np.arange(left_of_first_bin, right_of_last_bin + d, d))
plt.show()

# %%
all_agreed_dist.mean()
# Out:
# 5.384

# %%
agreed_dist.mean()
# Out:
# 5.6
